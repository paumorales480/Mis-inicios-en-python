# %% [markdown]
# #### Entradas y salidas

# %%
#Pedir información --> input

nombre = input("Ingresa tu nombre: ")
edad = input("Ingresa tu edad: ")

print("¡Hola," + nombre + "!")
print("Tienes ", edad, " años")
# Out:
# ¡Hola,Paulina!
# Tienes  12  años

# %% [markdown]
# Impoltante: La función input() siempre devuelve una cadena de texto. Si deseas trabajar con otros tipos de datos, como números enteros o flotantes, debes realizar una conversión explícita utilizando funciones como int() o float().

# %%
edad = int(input("Ingresa tu edad: "))

if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad, tienes:", edad, " años")
# Out:
# Eres menor de edad, tienes: 12  años

# %%
from math import sqrt


resultado = sqrt(25)
print(resultado)  # Imprime 5.0
# Out:
# 5.0

# %%
import random
import datetime


numero_aleatorio = random.randint(1, 10)
print(numero_aleatorio)  # Imprime un número entero aleatorio entre 1 y 10


fecha_actual = datetime.datetime.now()
print(fecha_actual)  # Imprime la fecha y hora actual
# Out:
# 7
# 2026-05-22 17:02:17.331302
